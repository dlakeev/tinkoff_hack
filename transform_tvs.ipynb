# %%
import pandas as pd
from server_config import ENGINE_LINK
from sqlalchemy import create_engine

import re

from pymorphy2 import MorphAnalyzer
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords
import nltk
nltk.download('punkt')
nltk.download('wordnet')

from sklearn.feature_extraction.text import TfidfVectorizer

from joblib import Parallel, delayed

from tqdm import tqdm
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\skliz\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\skliz\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
with create_engine(ENGINE_LINK).connect() as conn:
    df = pd.read_sql("select * from tvs where total_duration notnull", conn)
    
df.tail()
# Out:
#           type                 title_ru            title_eng  \
# 176440  Сериал                На замену     The Replacements
# 176441  Сериал                     Срок                 Time
# 176442  Сериал  Убийство первой степени  Murder in the First
# 176443  Сериал                  Борджиа               Borgia
# 176444  Сериал         Самый лучший хит         The Best Hit
#
#                                               description year_start year_end  \
# 176440  Тодд и Райли жили в приюте, не зная, что случи...       2006     2009
# 176441  Марк Кобден осужден на четыре года за неосторо...       2021     2021
# 176442  В центре сюжета сериала, действие которого раз...       2014     2016
# 176443  Шокирующий путь восхождения к власти и доминир...       2011     2014
# 176444  Юн Хён Дже (Юн Ши Юн) — музыкальный гений, уча...       2017     2017
#
#                                 genres myshows_rating myshows_num kp_rating  \
# 176440    Семейный,Детский,Приключения           3.74         300     5.829
# 176441                   Драма,Триллер           4.05        1112     7.557
# 176442         Криминал,Драма,Детектив           3.51        1173     6.595
# 176443  Приключения,Драма,Исторический           4.04        1140     7.863
# 176444     Драма,Музыкальный,Романтика           4.32        1394     7.781
#
#        kp_num imdb_rating imdb_num         country           total_duration  \
# 176440   1317         5.8     2983             США   1 день 3 часа 30 минут
# 176441  29158         8.2    20416  Великобритания          3 часа 2 минуты
# 176442   1627         7.2     7301             США         22 часа 56 минут
# 176443  25408         7.8     6721         Франция  1 день 12 часов 6 минут
# 176444   2905         7.6      764     Южная,Корея                 16 часов
#
#        series_duration seasons      production  \
# 176440         22 мин.       2  Disney Channel
# 176441         60 мин.       1         BBC One
# 176442         43 мин.       3       TNT DRAMA
# 176443         57 мин.       3          Canal+
# 176444         30 мин.       1            KBS2
#
#                                                    poster  \
# 176440  https://media.myshows.me/shows/1920/2/24/22458...
# 176441  https://media.myshows.me/shows/1920/2/df/2dfab...
# 176442  https://media.myshows.me/shows/1920/f/2c/f2cf9...
# 176443  https://media.myshows.me/shows/1920/d/4d/d4d04...
# 176444  https://media.myshows.me/shows/1920/6/57/65785...
#
#                                   link
# 176440  https://myshows.me/view/13300/
# 176441  https://myshows.me/view/73329/
# 176442  https://myshows.me/view/35641/
# 176443  https://myshows.me/view/21508/
# 176444  https://myshows.me/view/53621/

# %%
df['type'] = df['type'].map({'Фильм' : 'film', 'Аниме' : 'series', 'Мультфильм' : 'film', 'Мультсериал' : 'series', 'Сериал' : 'series'})

# %%
def transform_duration(x):
    x = re.sub(' +', '', x)
    
    res = 0
    
    TIME = {
        'мес' : 720, # 30 дней
        'нед' : 168,
        'день' : 24,
        'дня': 24,
        'дней' : 24,
        'час' : 1,
        'мин' : 1/60
    }
    
    for key in TIME.keys():
        try:
            res += (int(re.search(r'\d+', re.search(fr'\d+{key}', x).group(0)).group(0)) * TIME[key])
        except: pass
        
    return res

# %%
df['total_duration'] = df['total_duration'].map(transform_duration)

# %%
df['total_duration'].describe()
# Out:
# count    176445.000000
# mean          9.268295
# std          80.468568
# min           0.000000
# 25%           1.250000
# 50%           1.583333
# 75%           2.433333
# max        7598.316667
# Name: total_duration, dtype: float64

# %%
df = df.loc[(df['year_start'].isna()==False) & (df['title_ru'].isna()==False) & (df['description'].isna() == False)].reset_index(drop=True)

# %%
def clean_text(x: str,
               morph: MorphAnalyzer = MorphAnalyzer(),
               sno: SnowballStemmer = SnowballStemmer('russian'),
               stop_words: list = stopwords.words('russian'),
               min_len_word: int = 2) -> str:
    x = x.lower()                      # Приведение к нижнему регистру
    x = re.sub(r'[^а-я]+', ' ', x)     # Удаление всех символов, цифр
    x = re.sub(r' +', ' ', x)          # Удаление повторяющихся пробелов

    word_tokenization = x.split(' ')   # Токенизация слов

    result_sentance = []

    # Приведение слов к нормальной форме (леммер + стеммер для причастий)
    for word in word_tokenization:
        if 'PRTF' in morph.parse(word.strip())[0].tag or 'PRTS' in morph.parse(word.strip())[0].tag:
            result_word = sno.stem(word)
        else:
            result_word = morph.parse(word.strip())[0].normal_form

        if result_word not in stop_words and len(result_word) > min_len_word:
            result_sentance.append(result_word)

    return ' '.join(result_sentance)

# %%
clean_description = Parallel(n_jobs=-1)(delayed(clean_text)(t) for t in tqdm(df['description']))
df['clean_description'] = clean_description
# Out:
# 100%|██████████| 69505/69505 [15:33<00:00, 74.47it/s]

# %%
vectorizer = TfidfVectorizer(ngram_range=(1, 2))

X = vectorizer.fit_transform(df['clean_description'])

# %%
df['vectorizer'] = list(X)

# %%
df['show_id'] = df['title_ru'] + '_' + df['year_start'] + '_' + df['type']

# %%
df[['show_id', 'total_duration', 'kp_rating', 'imdb_rating', 'genres', 'clean_description', 'vectorizer']]
# Out:
#                                                  show_id  total_duration  \
# 0                         Вставай! Оторвись!_2020_series        1.000000
# 1      У нашего старшего брата проблемы с головой_201...        3.583333
# 2                        Супер братья Сейшин_2013_series        0.933333
# 3                    Стальные Хроники Царств_2007_series        9.166667
# 4                              Метка дракона_2014_series        5.000000
# ...                                                  ...             ...
# 69500                              На замену_2006_series       27.500000
# 69501                                   Срок_2021_series        3.033333
# 69502                Убийство первой степени_2014_series       22.933333
# 69503                                Борджиа_2011_series       36.100000
# 69504                       Самый лучший хит_2017_series       16.000000
#
#       kp_rating imdb_rating                                  genres  \
# 0          None        None                           Аниме,Комедия
# 1          None        None        Боевик,Приключения,Аниме,Комедия
# 2          None        None                           Комедия,Аниме
# 3          None        None          Приключения,Аниме,Исторический
# 4         5.995         6.6  Аниме,Романтика,Фэнтези,Комедия,Боевик
# ...         ...         ...                                     ...
# 69500     5.829         5.8            Семейный,Детский,Приключения
# 69501     7.557         8.2                           Драма,Триллер
# 69502     6.595         7.2                 Криминал,Драма,Детектив
# 69503     7.863         7.8          Приключения,Драма,Исторический
# 69504     7.781         7.6             Драма,Музыкальный,Романтика
#
#                                        clean_description  \
# 0      история творческий трение ревность среди юный ...
# 1      приключение четыре ученик путь совершенствован...
# 2      история вращаться вокруг сестра младший брат ч...
# 3      существовать печать который должный носить изб...
# 4      посреди могучий держава лежать небольшой горны...
# ...                                                  ...
# 69500  тодда райли жить приют знать случиться биологи...
# 69501  марк кобден осужд четыре год неосторожный убий...
# 69502  центр сюжет сериал действие который разворачив...
# 69503  шокир путь восхождение власть доминирование са...
# 69504  юный дже юный юный музыкальный гений участник ...
#
#                                               vectorizer
# 0        (0, 1449085)\t0.2874276844462563\n  (0, 5490...
# 1        (0, 1452215)\t0.2840117755195547\n  (0, 5908...
# 2        (0, 720987)\t0.17603081763783227\n  (0, 4103...
# 3        (0, 1060006)\t0.15623172751978565\n  (0, 589...
# 4        (0, 360289)\t0.05407970629428435\n  (0, 6944...
# ...                                                  ...
# 69500    (0, 427515)\t0.11044447762839461\n  (0, 1660...
# 69501    (0, 1115724)\t0.1529117029917302\n  (0, 8783...
# 69502    (0, 1655193)\t0.1693229607495187\n  (0, 1464...
# 69503    (0, 944170)\t0.12858310246141283\n  (0, 3914...
# 69504    (0, 613041)\t0.09828099894710936\n  (0, 8743...
#
# [69505 rows x 7 columns]

# %%
df[['show_id', 'total_duration', 'kp_rating', 'imdb_rating', 'genres', 'clean_description', 'vectorizer']].to_csv('data/tvs_bd.csv', index=False)
